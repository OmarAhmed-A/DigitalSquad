# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np


class DeepQNetwork(nn.Module):
    def __init__(self, lr, input_dims, fc1_dims, fc2_dims, n_actions):
        super(DeepQNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)

        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss = nn.MSELoss()
        self.device = T.device("cuda:0" if T.cuda.is_available() else "cpu")
        self.to(self.device)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)

        return actions


class Agent:
    def __init__(
        self,
        gamma,
        epsilon,
        lr,
        input_dims,
        batch_size,
        n_actions,
        max_mem_size=100000,
        eps_end=0.05,
        eps_dec=5e-6,
    ):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.lr = lr
        self.action_space = [0, 1, 2, 3]  # ['N', 'S', 'E', 'W']
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0
        self.iter_cntr = 0
        self.replace_target = 100

        self.Q_eval = DeepQNetwork(
            lr, n_actions=n_actions, input_dims=input_dims, fc1_dims=256, fc2_dims=256
        )
        self.state_memory = np.zeros(
            (self.mem_size, *input_dims), dtype=np.float32
        )  
        self.new_state_memory = np.zeros((self.mem_size, *input_dims), dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=bool)

    def store_transition(self, state, action, reward, state_, terminal):
        index = self.mem_cntr % self.mem_size

        arr = np.concatenate(
            (np.array(state[0]), state[1], np.concatenate(state[2]),)
            )
        arr = np.pad(arr, (0, 14 - len(arr)), mode="constant")

        self.state_memory[index] = arr

        arr = np.concatenate(
            (np.array(state_[0]), state_[1], np.concatenate(state_[2]),)
        )
        arr = np.pad(arr, (0, 14 - len(arr)), mode="constant")

        self.new_state_memory[index] = arr
        self.reward_memory[index] = reward
        self.action_memory[index] = action
        self.terminal_memory[index] = terminal

        self.mem_cntr += 1

    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            arr = np.concatenate(
                (
                    np.array(observation[0]),
                    observation[1],
                    np.concatenate(observation[2]),
                )
            )
            arr = np.pad(arr, (0, 14 - len(arr)), mode="constant")
            state = T.tensor(np.array(arr), dtype=self.Q_eval.fc1.weight.dtype,).to(
                self.Q_eval.device
            )
            actions = self.Q_eval.forward(state)
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    def learn(self):
        if self.mem_cntr < self.batch_size:
            return

        self.Q_eval.optimizer.zero_grad()

        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, self.batch_size, replace=False)
        batch_index = np.arange(self.batch_size, dtype=np.int32)

        state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
        new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
        action_batch = self.action_memory[batch]
        reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
        terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)

        q_eval = self.Q_eval.forward(state_batch)[batch_index, action_batch]

        q_next = self.Q_eval.forward(new_state_batch)
        q_next[terminal_batch] = 0.0

        q_target = reward_batch + self.gamma * T.max(q_next, dim=1)[0]

        loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
        loss.backward()
        self.Q_eval.optimizer.step()

        self.iter_cntr += 1
        self.epsilon = (
            self.epsilon - self.eps_dec if self.epsilon > self.eps_min else self.eps_min
        )

# %%
import sys
import numpy as np
import math
import random
import json
import requests
import random
import numpy as np
import gym
import time

sys.path.append('c://Users/omara/Desktop/VSCODE/DigitalSquad/gym-maze/')
import gym_maze
from gym_maze.envs.maze_manager import MazeManager
from riddle_solvers import *

# %%
def manhattan_distance(start, end):
    return abs(start[0] - end[0]) + abs(start[1] - end[1])

def get_reward(obv,obv_,info, vis,cell_vis):
    if obv[0][0] == obv_[0][0] and obv[0][1] == obv_[0][1]:
        return -20000
    #if in cell visted 
    elif obv[0] in cell_vis:
        return -10000

    elif obv[0][0] == 9 and obv[0][1] == 9:
        return 1000000    
    # {'rescued_items': 0, 'riddle_type': None, 'riddle_question': None}
    elif info[riddle_type]  != None and info[riddle_type] not in vis:
        return 1000
    else:
        return (0 - manhattan_distance(obv[0], np.array((9, 9))))

# %%
sample_maze = np.load("sample_maze1.npy")
agent_id = "9" # add your agent id here
    
manager = MazeManager()
manager.init_maze(agent_id, maze_cells=sample_maze, )
env = manager.maze_map[agent_id]

riddle_solvers = {'cipher': cipher_solver, 'captcha': captcha_solver, 'pcap': pcap_solver, 'server': server_solver}
maze = {}
states = {}


maze['maze'] = env.maze_view.maze.maze_cells.tolist()
maze['rescue_items'] = list(manager.rescue_items_dict.keys())

MAX_T = 500
RENDER_MAZE = True

agent = Agent(gamma=0.99, epsilon=1.0, batch_size=64, n_actions=4, eps_end=0.001,
                input_dims=[14,], lr=0.001)
scores, eps_history = [], []
n_games = 500
timeout = 300
for i in range(n_games):
    score = 0
    done = False
    observation = env.reset()
    manager.render(agent_id)
    num_steps = 0
    start_time = time.time()
    visited = set(())
    cell_visited = set(())

    
    passed_time = 0
    while not done and passed_time < timeout and  num_steps < MAX_T:
        passed_time = time.time() - start_time
        action = agent.choose_action(observation)
        mapping = ['N', 'S', 'E', 'W']

        actionChar = mapping[action]

        observation_, _, done,_, info = manager.step(agent_id, actionChar)
        # print(info)
        if info['riddle_type']  != None:
            # riddle_solver = riddle_solvers[info['riddle_type']]
            # answer = riddle_solvers(info['riddle_question'])
            # manager.answer_riddle(agent_id, answer)
            visited.add(info['riddle_type'])

        cell_visited.add((observation_[0][0], observation_[0][1]))
        manager.render(agent_id)
        reward = get_reward(observation_, observation, info,visited, cell_visited)
        score += reward

        num_steps += 1
        if np.array_equal(observation_[0], (9,9)):
            manager.set_done(agent_id)
            done = True
        agent.store_transition(observation, action, reward, 
                                observation_, done)
        agent.learn()
        observation = observation_
    scores.append(score)
    eps_history.append(agent.epsilon)

    avg_score = np.mean(scores[-100:])

    print('episode ', i, 'score %.2f' % score,
            'average score %.2f' % avg_score,
            'epsilon %.2f' % agent.epsilon, 'num_steps' , num_steps,
              'time %.2f' % passed_time, 'done', done)
# Out:
# 0 rescue items
# 0 rescue items
# 0 rescue items
# 0 rescue items
# 0 rescue items
# episode  0 score -10000000.00 average score -10000000.00 epsilon 1.00 num_steps 500 time 12.22 done False
# episode  1 score -10000000.00 average score -10000000.00 epsilon 1.00 num_steps 500 time 11.93 done False
# episode  2 score -10000000.00 average score -10000000.00 epsilon 0.99 num_steps 500 time 11.64 done False
# episode  3 score -10000000.00 average score -10000000.00 epsilon 0.99 num_steps 500 time 11.61 done False
# episode  4 score -10000000.00 average score -10000000.00 epsilon 0.99 num_steps 500 time 11.58 done False
# episode  5 score -10000000.00 average score -10000000.00 epsilon 0.99 num_steps 500 time 10.73 done False
# episode  6 score -10000000.00 average score -10000000.00 epsilon 0.98 num_steps 500 time 11.60 done False
# episode  7 score -10000000.00 average score -10000000.00 epsilon 0.98 num_steps 500 time 12.57 done False
# episode  8 score -10000000.00 average score -10000000.00 epsilon 0.98 num_steps 500 time 11.73 done False
# episode  9 score -10000000.00 average score -10000000.00 epsilon 0.98 num_steps 500 time 11.31 done False
# episode  10 score -10000000.00 average score -10000000.00 epsilon 0.97 num_steps 500 time 11.63 done False
# episode  11 score -10000000.00 average score -10000000.00 epsilon 0.97 num_steps 500 time 11.42 done False
# episode  12 score -10000000.00 average score -10000000.00 epsilon 0.97 num_steps 500 time 12.29 done False
# episode  13 score -10000000.00 average score -10000000.00 epsilon 0.97 num_steps 500 time 13.75 done False
# episode  14 score -10000000.00 average score -10000000.00 epsilon 0.96 num_steps 500 time 12.10 done False
# episode  15 score -10000000.00 average score -10000000.00 epsilon 0.96 num_steps 500 time 11.44 done False
# episode  16 score -10000000.00 average score -10000000.00 epsilon 0.96 num_steps 500 time 12.39 done False
# episode  17 score -10000000.00 average score -10000000.00 epsilon 0.96 num_steps 500 time 11.37 done False
# episode  18 score -10000000.00 average score -10000000.00 epsilon 0.95 num_steps 500 time 12.39 done False
# episode  19 score -10000000.00 average score -10000000.00 epsilon 0.95 num_steps 500 time 12.10 done False
# episode  20 score -10000000.00 average score -10000000.00 epsilon 0.95 num_steps 500 time 11.92 done False
# episode  21 score -10000000.00 average score -10000000.00 epsilon 0.95 num_steps 500 time 12.38 done False
# episode  22 score -3940000.00 average score -9736521.74 epsilon 0.94 num_steps 197 time 5.13 done True
# episode  23 score -10000000.00 average score -9747500.00 epsilon 0.94 num_steps 500 time 14.60 done False
# episode  24 score -10000000.00 average score -9757600.00 epsilon 0.94 num_steps 500 time 9.68 done False
# episode  25 score -10000000.00 average score -9766923.08 epsilon 0.94 num_steps 500 time 9.89 done False
# episode  26 score -4700000.00 average score -9579259.26 epsilon 0.94 num_steps 235 time 4.58 done True
# episode  27 score -10000000.00 average score -9594285.71 epsilon 0.93 num_steps 500 time 13.58 done False
# episode  28 score -10000000.00 average score -9608275.86 epsilon 0.93 num_steps 500 time 10.04 done False
# episode  29 score -10000000.00 average score -9621333.33 epsilon 0.93 num_steps 500 time 12.75 done False
# episode  30 score -10000000.00 average score -9633548.39 epsilon 0.93 num_steps 500 time 9.83 done False
# episode  31 score -10000000.00 average score -9645000.00 epsilon 0.92 num_steps 500 time 14.81 done False
# episode  32 score -10000000.00 average score -9655757.58 epsilon 0.92 num_steps 500 time 11.64 done False
# episode  33 score -10000000.00 average score -9665882.35 epsilon 0.92 num_steps 500 time 16.75 done False
# episode  34 score -10000000.00 average score -9675428.57 epsilon 0.92 num_steps 500 time 20.83 done False
# episode  35 score -10000000.00 average score -9684444.44 epsilon 0.91 num_steps 500 time 12.32 done False
# episode  36 score -10000000.00 average score -9692972.97 epsilon 0.91 num_steps 500 time 12.21 done False
# episode  37 score -10000000.00 average score -9701052.63 epsilon 0.91 num_steps 500 time 12.32 done False
# episode  38 score -4320000.00 average score -9563076.92 epsilon 0.91 num_steps 216 time 5.13 done True
# episode  39 score -10000000.00 average score -9574000.00 epsilon 0.90 num_steps 500 time 12.25 done False
# episode  40 score -10000000.00 average score -9584390.24 epsilon 0.90 num_steps 500 time 12.37 done False
# episode  41 score -10000000.00 average score -9594285.71 epsilon 0.90 num_steps 500 time 13.54 done False
# episode  42 score -9840000.00 average score -9600000.00 epsilon 0.90 num_steps 492 time 13.05 done True
# episode  43 score -10000000.00 average score -9609090.91 epsilon 0.89 num_steps 500 time 12.33 done False
# episode  44 score -10000000.00 average score -9617777.78 epsilon 0.89 num_steps 500 time 14.47 done False
# episode  45 score -10000000.00 average score -9626086.96 epsilon 0.89 num_steps 500 time 12.92 done False
# episode  46 score -10000000.00 average score -9634042.55 epsilon 0.89 num_steps 500 time 12.58 done False
# episode  47 score -10000000.00 average score -9641666.67 epsilon 0.88 num_steps 500 time 12.41 done False
# episode  48 score -10000000.00 average score -9648979.59 epsilon 0.88 num_steps 500 time 15.91 done False
# episode  49 score -10000000.00 average score -9656000.00 epsilon 0.88 num_steps 500 time 13.81 done False
# episode  50 score -10000000.00 average score -9662745.10 epsilon 0.88 num_steps 500 time 14.70 done False
# episode  51 score -10000000.00 average score -9669230.77 epsilon 0.87 num_steps 500 time 18.22 done False
# episode  52 score -8500000.00 average score -9647169.81 epsilon 0.87 num_steps 425 time 16.50 done True
# episode  53 score -10000000.00 average score -9653703.70 epsilon 0.87 num_steps 500 time 14.22 done False
# episode  54 score -10000000.00 average score -9660000.00 epsilon 0.87 num_steps 500 time 15.25 done False
# episode  55 score -10000000.00 average score -9666071.43 epsilon 0.86 num_steps 500 time 13.62 done False
# episode  56 score -10000000.00 average score -9671929.82 epsilon 0.86 num_steps 500 time 17.30 done False
# episode  57 score -10000000.00 average score -9677586.21 epsilon 0.86 num_steps 500 time 14.77 done False
# episode  58 score -10000000.00 average score -9683050.85 epsilon 0.86 num_steps 500 time 13.17 done False
# episode  59 score -10000000.00 average score -9688333.33 epsilon 0.85 num_steps 500 time 13.10 done False
# episode  60 score -10000000.00 average score -9693442.62 epsilon 0.85 num_steps 500 time 13.93 done False
# episode  61 score -10000000.00 average score -9698387.10 epsilon 0.85 num_steps 500 time 16.31 done False
# episode  62 score -10000000.00 average score -9703174.60 epsilon 0.85 num_steps 500 time 13.25 done False
# episode  63 score -10000000.00 average score -9707812.50 epsilon 0.84 num_steps 500 time 12.79 done False
# episode  64 score -10000000.00 average score -9712307.69 epsilon 0.84 num_steps 500 time 17.48 done False
# episode  65 score -8260000.00 average score -9690303.03 epsilon 0.84 num_steps 413 time 12.43 done True
# episode  66 score -2280000.00 average score -9579701.49 epsilon 0.84 num_steps 114 time 3.98 done True
# episode  67 score -9440000.00 average score -9577647.06 epsilon 0.84 num_steps 472 time 14.28 done True
# episode  68 score -10000000.00 average score -9583768.12 epsilon 0.83 num_steps 500 time 14.73 done False
# episode  69 score -9380000.00 average score -9580857.14 epsilon 0.83 num_steps 469 time 12.32 done True
# episode  70 score -10000000.00 average score -9586760.56 epsilon 0.83 num_steps 500 time 13.91 done False
# episode  71 score -10000000.00 average score -9592500.00 epsilon 0.83 num_steps 500 time 13.55 done False
# episode  72 score -10000000.00 average score -9598082.19 epsilon 0.83 num_steps 500 time 13.86 done False
# episode  73 score -10000000.00 average score -9603513.51 epsilon 0.82 num_steps 500 time 15.67 done False
# episode  74 score -10000000.00 average score -9608800.00 epsilon 0.82 num_steps 500 time 17.28 done False
# episode  75 score -10000000.00 average score -9613947.37 epsilon 0.82 num_steps 500 time 16.38 done False
# episode  76 score -10000000.00 average score -9618961.04 epsilon 0.82 num_steps 500 time 15.69 done False
# episode  77 score -10000000.00 average score -9623846.15 epsilon 0.81 num_steps 500 time 13.87 done False
# episode  78 score -10000000.00 average score -9628607.59 epsilon 0.81 num_steps 500 time 13.89 done False
# episode  79 score -10000000.00 average score -9633250.00 epsilon 0.81 num_steps 500 time 14.61 done False
# episode  80 score -2860000.00 average score -9549629.63 epsilon 0.81 num_steps 143 time 2.82 done True
# episode  81 score -10000000.00 average score -9555121.95 epsilon 0.80 num_steps 500 time 14.62 done False
# episode  82 score -10000000.00 average score -9560481.93 epsilon 0.80 num_steps 500 time 14.25 done False
# episode  83 score -10000000.00 average score -9565714.29 epsilon 0.80 num_steps 500 time 15.15 done False
# episode  84 score -4340000.00 average score -9504235.29 epsilon 0.80 num_steps 217 time 7.67 done True
# episode  85 score -10000000.00 average score -9510000.00 epsilon 0.80 num_steps 500 time 14.83 done False
# episode  86 score -3780000.00 average score -9444137.93 epsilon 0.79 num_steps 189 time 4.85 done True
# episode  87 score -10000000.00 average score -9450454.55 epsilon 0.79 num_steps 500 time 12.93 done False
# episode  88 score -10000000.00 average score -9456629.21 epsilon 0.79 num_steps 500 time 14.63 done False
# episode  89 score -10000000.00 average score -9462666.67 epsilon 0.79 num_steps 500 time 14.93 done False
# episode  90 score -10000000.00 average score -9468571.43 epsilon 0.78 num_steps 500 time 13.17 done False
# episode  91 score -10000000.00 average score -9474347.83 epsilon 0.78 num_steps 500 time 12.98 done False
# episode  92 score -10000000.00 average score -9480000.00 epsilon 0.78 num_steps 500 time 14.29 done False
# episode  93 score -10000000.00 average score -9485531.91 epsilon 0.78 num_steps 500 time 13.57 done False
# episode  94 score -10000000.00 average score -9490947.37 epsilon 0.77 num_steps 500 time 13.59 done False
# episode  95 score -10000000.00 average score -9496250.00 epsilon 0.77 num_steps 500 time 13.57 done False
# episode  96 score -10000000.00 average score -9501443.30 epsilon 0.77 num_steps 500 time 13.32 done False
# episode  97 score -10000000.00 average score -9506530.61 epsilon 0.77 num_steps 500 time 13.02 done False
# episode  98 score -10000000.00 average score -9511515.15 epsilon 0.76 num_steps 500 time 13.91 done False
# episode  99 score -6720000.00 average score -9483600.00 epsilon 0.76 num_steps 336 time 9.00 done True
# episode  100 score -10000000.00 average score -9483600.00 epsilon 0.76 num_steps 500 time 11.97 done False
# episode  101 score -4740000.00 average score -9431000.00 epsilon 0.76 num_steps 237 time 9.43 done True
# episode  102 score -10000000.00 average score -9431000.00 epsilon 0.76 num_steps 500 time 13.62 done False
# episode  103 score -7040000.00 average score -9401400.00 epsilon 0.76 num_steps 352 time 10.16 done True
# episode  104 score -10000000.00 average score -9401400.00 epsilon 0.75 num_steps 500 time 13.43 done False
# episode  105 score -6100000.00 average score -9362400.00 epsilon 0.75 num_steps 305 time 8.50 done True
# episode  106 score -10000000.00 average score -9362400.00 epsilon 0.75 num_steps 500 time 13.45 done False
# episode  107 score -10000000.00 average score -9362400.00 epsilon 0.75 num_steps 500 time 14.16 done False
# episode  108 score -1660000.00 average score -9279000.00 epsilon 0.75 num_steps 83 time 2.73 done True
# episode  109 score -10000000.00 average score -9279000.00 epsilon 0.74 num_steps 500 time 13.60 done False
# episode  110 score -10000000.00 average score -9279000.00 epsilon 0.74 num_steps 500 time 15.74 done False
# episode  111 score -980000.00 average score -9188800.00 epsilon 0.74 num_steps 49 time 1.16 done True
# episode  112 score -10000000.00 average score -9188800.00 epsilon 0.74 num_steps 500 time 14.33 done False
# episode  113 score -10000000.00 average score -9188800.00 epsilon 0.74 num_steps 500 time 14.41 done False
# episode  114 score -10000000.00 average score -9188800.00 epsilon 0.73 num_steps 500 time 15.33 done False
# episode  115 score -10000000.00 average score -9188800.00 epsilon 0.73 num_steps 500 time 13.68 done False
# episode  116 score -10000000.00 average score -9188800.00 epsilon 0.73 num_steps 500 time 13.87 done False
# episode  117 score -10000000.00 average score -9188800.00 epsilon 0.73 num_steps 500 time 15.84 done False
# episode  118 score -10000000.00 average score -9188800.00 epsilon 0.72 num_steps 500 time 13.32 done False
# episode  119 score -10000000.00 average score -9188800.00 epsilon 0.72 num_steps 500 time 13.19 done False
# episode  120 score -5040000.00 average score -9139200.00 epsilon 0.72 num_steps 252 time 8.25 done True
# episode  121 score -10000000.00 average score -9139200.00 epsilon 0.72 num_steps 500 time 16.12 done False
# episode  122 score -7220000.00 average score -9172000.00 epsilon 0.72 num_steps 361 time 14.91 done True
# episode  123 score -10000000.00 average score -9172000.00 epsilon 0.71 num_steps 500 time 14.98 done False
# episode  124 score -10000000.00 average score -9172000.00 epsilon 0.71 num_steps 500 time 14.11 done False
# episode  125 score -10000000.00 average score -9172000.00 epsilon 0.71 num_steps 500 time 17.33 done False
# episode  126 score -8100000.00 average score -9206000.00 epsilon 0.71 num_steps 405 time 15.02 done True
# episode  127 score -6320000.00 average score -9169200.00 epsilon 0.70 num_steps 316 time 10.23 done True
# episode  128 score -10000000.00 average score -9169200.00 epsilon 0.70 num_steps 500 time 15.01 done False
# episode  129 score -9120000.00 average score -9160400.00 epsilon 0.70 num_steps 456 time 16.37 done True
# episode  130 score -8540000.00 average score -9145800.00 epsilon 0.70 num_steps 427 time 15.57 done True
# episode  131 score -2960000.00 average score -9075400.00 epsilon 0.70 num_steps 148 time 4.01 done True
# episode  132 score -10000000.00 average score -9075400.00 epsilon 0.69 num_steps 500 time 15.25 done False
# episode  133 score -10000000.00 average score -9075400.00 epsilon 0.69 num_steps 500 time 16.96 done False
# episode  134 score -10000000.00 average score -9075400.00 epsilon 0.69 num_steps 500 time 17.06 done False
# episode  135 score -10000000.00 average score -9075400.00 epsilon 0.69 num_steps 500 time 15.07 done False
# episode  136 score -10000000.00 average score -9075400.00 epsilon 0.68 num_steps 500 time 14.15 done False
# episode  137 score -10000000.00 average score -9075400.00 epsilon 0.68 num_steps 500 time 15.53 done False
# episode  138 score -10000000.00 average score -9132200.00 epsilon 0.68 num_steps 500 time 15.33 done False
# episode  139 score -10000000.00 average score -9132200.00 epsilon 0.68 num_steps 500 time 18.61 done False
# episode  140 score -10000000.00 average score -9132200.00 epsilon 0.67 num_steps 500 time 19.44 done False
# episode  141 score -10000000.00 average score -9132200.00 epsilon 0.67 num_steps 500 time 18.45 done False
# episode  142 score -10000000.00 average score -9133800.00 epsilon 0.67 num_steps 500 time 19.50 done False
# episode  143 score -10000000.00 average score -9133800.00 epsilon 0.67 num_steps 500 time 21.43 done False
# episode  144 score -10000000.00 average score -9133800.00 epsilon 0.66 num_steps 500 time 15.22 done False
# episode  145 score -10000000.00 average score -9133800.00 epsilon 0.66 num_steps 500 time 17.82 done False
# episode  146 score -9480000.00 average score -9128600.00 epsilon 0.66 num_steps 474 time 15.77 done True
# episode  147 score -10000000.00 average score -9128600.00 epsilon 0.66 num_steps 500 time 16.17 done False
# episode  148 score -10000000.00 average score -9128600.00 epsilon 0.65 num_steps 500 time 19.53 done False
# episode  149 score -10000000.00 average score -9128600.00 epsilon 0.65 num_steps 500 time 17.36 done False
# episode  150 score -10000000.00 average score -9128600.00 epsilon 0.65 num_steps 500 time 17.24 done False
# episode  151 score -10000000.00 average score -9128600.00 epsilon 0.65 num_steps 500 time 17.80 done False
# episode  152 score -5020000.00 average score -9093800.00 epsilon 0.65 num_steps 251 time 7.73 done True
# episode  153 score -8820000.00 average score -9082000.00 epsilon 0.64 num_steps 441 time 14.84 done True
# episode  154 score -10000000.00 average score -9082000.00 epsilon 0.64 num_steps 500 time 19.36 done False
# episode  155 score -10000000.00 average score -9082000.00 epsilon 0.64 num_steps 500 time 16.56 done False
# episode  156 score -10000000.00 average score -9082000.00 epsilon 0.64 num_steps 500 time 19.07 done False
# episode  157 score -7040000.00 average score -9052400.00 epsilon 0.63 num_steps 352 time 12.01 done True
# episode  158 score -10000000.00 average score -9052400.00 epsilon 0.63 num_steps 500 time 17.17 done False
# episode  159 score -10000000.00 average score -9052400.00 epsilon 0.63 num_steps 500 time 16.00 done False
# episode  160 score -10000000.00 average score -9052400.00 epsilon 0.63 num_steps 500 time 19.80 done False
# episode  161 score -10000000.00 average score -9052400.00 epsilon 0.62 num_steps 500 time 17.82 done False
# episode  162 score -10000000.00 average score -9052400.00 epsilon 0.62 num_steps 500 time 23.11 done False
# episode  163 score -10000000.00 average score -9052400.00 epsilon 0.62 num_steps 500 time 21.99 done False
# episode  164 score -5200000.00 average score -9004400.00 epsilon 0.62 num_steps 260 time 10.35 done True
# episode  165 score -10000000.00 average score -9021800.00 epsilon 0.61 num_steps 500 time 16.61 done False
# episode  166 score -10000000.00 average score -9099000.00 epsilon 0.61 num_steps 500 time 17.46 done False
# episode  167 score -10000000.00 average score -9104600.00 epsilon 0.61 num_steps 500 time 17.80 done False
# episode  168 score -10000000.00 average score -9104600.00 epsilon 0.61 num_steps 500 time 16.98 done False
# episode  169 score -10000000.00 average score -9110800.00 epsilon 0.60 num_steps 500 time 17.86 done False
# episode  170 score -10000000.00 average score -9110800.00 epsilon 0.60 num_steps 500 time 18.08 done False
# episode  171 score -10000000.00 average score -9110800.00 epsilon 0.60 num_steps 500 time 18.37 done False
# episode  172 score -5300000.00 average score -9063800.00 epsilon 0.60 num_steps 265 time 8.68 done True
# episode  173 score -3400000.00 average score -8997800.00 epsilon 0.60 num_steps 170 time 6.16 done True
# episode  174 score -10000000.00 average score -8997800.00 epsilon 0.60 num_steps 500 time 19.80 done False
# episode  175 score -10000000.00 average score -8997800.00 epsilon 0.59 num_steps 500 time 19.08 done False
# episode  176 score -10000000.00 average score -8997800.00 epsilon 0.59 num_steps 500 time 17.24 done False
# episode  177 score -10000000.00 average score -8997800.00 epsilon 0.59 num_steps 500 time 18.88 done False
# episode  178 score -5500000.00 average score -8952800.00 epsilon 0.59 num_steps 275 time 10.62 done True
# episode  179 score -10000000.00 average score -8952800.00 epsilon 0.58 num_steps 500 time 19.10 done False
# episode  180 score -10000000.00 average score -9024200.00 epsilon 0.58 num_steps 500 time 20.75 done False
# episode  181 score -10000000.00 average score -9024200.00 epsilon 0.58 num_steps 500 time 20.94 done False
# episode  182 score -10000000.00 average score -9024200.00 epsilon 0.58 num_steps 500 time 30.25 done False
# episode  183 score -10000000.00 average score -9024200.00 epsilon 0.57 num_steps 500 time 19.31 done False
# episode  184 score -3540000.00 average score -9016200.00 epsilon 0.57 num_steps 177 time 8.01 done True
# episode  185 score -3560000.00 average score -8951800.00 epsilon 0.57 num_steps 178 time 12.47 done True
# episode  186 score -10000000.00 average score -9014000.00 epsilon 0.57 num_steps 500 time 16.96 done False
# episode  187 score -7340000.00 average score -8987400.00 epsilon 0.57 num_steps 367 time 15.09 done True
# episode  188 score -10000000.00 average score -8987400.00 epsilon 0.57 num_steps 500 time 20.39 done False
# episode  189 score -10000000.00 average score -8987400.00 epsilon 0.56 num_steps 500 time 20.54 done False
# episode  190 score -10000000.00 average score -8987400.00 epsilon 0.56 num_steps 500 time 21.15 done False
# episode  191 score -10000000.00 average score -8987400.00 epsilon 0.56 num_steps 500 time 22.38 done False
# episode  192 score -10000000.00 average score -8987400.00 epsilon 0.56 num_steps 500 time 22.26 done False
# episode  193 score -10000000.00 average score -8987400.00 epsilon 0.55 num_steps 500 time 22.98 done False
# episode  194 score -10000000.00 average score -8987400.00 epsilon 0.55 num_steps 500 time 22.52 done False
# episode  195 score -10000000.00 average score -8987400.00 epsilon 0.55 num_steps 500 time 18.65 done False
# episode  196 score -10000000.00 average score -8987400.00 epsilon 0.55 num_steps 500 time 19.09 done False
# episode  197 score -10000000.00 average score -8987400.00 epsilon 0.54 num_steps 500 time 25.48 done False
# episode  198 score -10000000.00 average score -8987400.00 epsilon 0.54 num_steps 500 time 21.72 done False
# episode  199 score -10000000.00 average score -9020200.00 epsilon 0.54 num_steps 500 time 20.19 done False
# episode  200 score -8940000.00 average score -9009600.00 epsilon 0.54 num_steps 447 time 18.16 done True
# episode  201 score -10000000.00 average score -9062200.00 epsilon 0.53 num_steps 500 time 22.84 done False
# episode  202 score -10000000.00 average score -9062200.00 epsilon 0.53 num_steps 500 time 18.65 done False
# episode  203 score -10000000.00 average score -9091800.00 epsilon 0.53 num_steps 500 time 21.05 done False
# episode  204 score -10000000.00 average score -9091800.00 epsilon 0.53 num_steps 500 time 21.14 done False
# episode  205 score -10000000.00 average score -9130800.00 epsilon 0.52 num_steps 500 time 28.91 done False
# episode  206 score -8540000.00 average score -9116200.00 epsilon 0.52 num_steps 427 time 17.99 done True
# episode  207 score -10000000.00 average score -9116200.00 epsilon 0.52 num_steps 500 time 19.11 done False
# episode  208 score -10000000.00 average score -9199600.00 epsilon 0.52 num_steps 500 time 20.97 done False
# episode  209 score -10000000.00 average score -9199600.00 epsilon 0.51 num_steps 500 time 20.80 done False
# episode  210 score -10000000.00 average score -9199600.00 epsilon 0.51 num_steps 500 time 24.06 done False
# episode  211 score -10000000.00 average score -9289800.00 epsilon 0.51 num_steps 500 time 21.86 done False
# episode  212 score -10000000.00 average score -9289800.00 epsilon 0.51 num_steps 500 time 20.73 done False
# episode  213 score -10000000.00 average score -9289800.00 epsilon 0.50 num_steps 500 time 23.48 done False
# episode  214 score -10000000.00 average score -9289800.00 epsilon 0.50 num_steps 500 time 25.91 done False
# episode  215 score -10000000.00 average score -9289800.00 epsilon 0.50 num_steps 500 time 21.14 done False
# episode  216 score -4140000.00 average score -9231200.00 epsilon 0.50 num_steps 207 time 8.26 done True
# episode  217 score -10000000.00 average score -9231200.00 epsilon 0.49 num_steps 500 time 25.37 done False
# episode  218 score -10000000.00 average score -9231200.00 epsilon 0.49 num_steps 500 time 25.80 done False
# episode  219 score -10000000.00 average score -9231200.00 epsilon 0.49 num_steps 500 time 24.91 done False
# episode  220 score -4280000.00 average score -9223600.00 epsilon 0.49 num_steps 214 time 11.13 done True
# episode  221 score -10000000.00 average score -9223600.00 epsilon 0.49 num_steps 500 time 26.70 done False
# episode  222 score -10000000.00 average score -9251400.00 epsilon 0.48 num_steps 500 time 26.53 done False
# episode  223 score -10000000.00 average score -9251400.00 epsilon 0.48 num_steps 500 time 25.04 done False
# episode  224 score -10000000.00 average score -9251400.00 epsilon 0.48 num_steps 500 time 24.25 done False
# episode  225 score -10000000.00 average score -9251400.00 epsilon 0.48 num_steps 500 time 21.48 done False
# episode  226 score -10000000.00 average score -9270400.00 epsilon 0.47 num_steps 500 time 21.48 done False
# episode  227 score -10000000.00 average score -9307200.00 epsilon 0.47 num_steps 500 time 33.56 done False
# episode  228 score -10000000.00 average score -9307200.00 epsilon 0.47 num_steps 500 time 26.10 done False
# episode  229 score -10000000.00 average score -9316000.00 epsilon 0.47 num_steps 500 time 25.13 done False
# episode  230 score -10000000.00 average score -9330600.00 epsilon 0.46 num_steps 500 time 28.87 done False
# episode  231 score -10000000.00 average score -9401000.00 epsilon 0.46 num_steps 500 time 32.72 done False
# episode  232 score -10000000.00 average score -9401000.00 epsilon 0.46 num_steps 500 time 37.23 done False
# episode  233 score -8340000.00 average score -9384400.00 epsilon 0.46 num_steps 417 time 34.12 done True
# episode  234 score -10000000.00 average score -9384400.00 epsilon 0.45 num_steps 500 time 19.88 done False
# episode  235 score -10000000.00 average score -9384400.00 epsilon 0.45 num_steps 500 time 20.81 done False
# episode  236 score -10000000.00 average score -9384400.00 epsilon 0.45 num_steps 500 time 22.37 done False
# episode  237 score -10000000.00 average score -9384400.00 epsilon 0.45 num_steps 500 time 18.35 done False
# episode  238 score -10000000.00 average score -9384400.00 epsilon 0.44 num_steps 500 time 21.50 done False
# episode  239 score -10000000.00 average score -9384400.00 epsilon 0.44 num_steps 500 time 18.44 done False
# episode  240 score -10000000.00 average score -9384400.00 epsilon 0.44 num_steps 500 time 17.22 done False
# episode  241 score -10000000.00 average score -9384400.00 epsilon 0.44 num_steps 500 time 17.89 done False
# episode  242 score -10000000.00 average score -9384400.00 epsilon 0.43 num_steps 500 time 18.16 done False
# episode  243 score -10000000.00 average score -9384400.00 epsilon 0.43 num_steps 500 time 19.31 done False
# episode  244 score -10000000.00 average score -9384400.00 epsilon 0.43 num_steps 500 time 16.27 done False
# episode  245 score -10000000.00 average score -9384400.00 epsilon 0.43 num_steps 500 time 15.67 done False
# episode  246 score -10000000.00 average score -9389600.00 epsilon 0.42 num_steps 500 time 17.00 done False
# episode  247 score -10000000.00 average score -9389600.00 epsilon 0.42 num_steps 500 time 18.19 done False
# episode  248 score -10000000.00 average score -9389600.00 epsilon 0.42 num_steps 500 time 15.59 done False
# episode  249 score -10000000.00 average score -9389600.00 epsilon 0.42 num_steps 500 time 15.00 done False
# episode  250 score -10000000.00 average score -9389600.00 epsilon 0.41 num_steps 500 time 28.16 done False
# episode  251 score -10000000.00 average score -9389600.00 epsilon 0.41 num_steps 500 time 20.90 done False
# episode  252 score -10000000.00 average score -9439400.00 epsilon 0.41 num_steps 500 time 17.97 done False
# episode  253 score -10000000.00 average score -9451200.00 epsilon 0.41 num_steps 500 time 16.94 done False
# episode  254 score -10000000.00 average score -9451200.00 epsilon 0.40 num_steps 500 time 17.06 done False
# episode  255 score -10000000.00 average score -9451200.00 epsilon 0.40 num_steps 500 time 15.99 done False
# episode  256 score -10000000.00 average score -9451200.00 epsilon 0.40 num_steps 500 time 19.07 done False
# episode  257 score -10000000.00 average score -9480800.00 epsilon 0.40 num_steps 500 time 13.44 done False
# episode  258 score -10000000.00 average score -9480800.00 epsilon 0.39 num_steps 500 time 15.14 done False
# episode  259 score -10000000.00 average score -9480800.00 epsilon 0.39 num_steps 500 time 13.88 done False
# episode  260 score -10000000.00 average score -9480800.00 epsilon 0.39 num_steps 500 time 15.20 done False
# episode  261 score -10000000.00 average score -9480800.00 epsilon 0.39 num_steps 500 time 12.12 done False
# episode  262 score -5100000.00 average score -9431800.00 epsilon 0.39 num_steps 255 time 6.03 done True
# episode  263 score -10000000.00 average score -9431800.00 epsilon 0.38 num_steps 500 time 12.74 done False
# episode  264 score -10000000.00 average score -9479800.00 epsilon 0.38 num_steps 500 time 16.38 done False
# episode  265 score -10000000.00 average score -9479800.00 epsilon 0.38 num_steps 500 time 14.67 done False
# episode  266 score -10000000.00 average score -9479800.00 epsilon 0.38 num_steps 500 time 11.96 done False
# episode  267 score -10000000.00 average score -9479800.00 epsilon 0.37 num_steps 500 time 12.28 done False
# episode  268 score -10000000.00 average score -9479800.00 epsilon 0.37 num_steps 500 time 12.69 done False
# episode  269 score -10000000.00 average score -9479800.00 epsilon 0.37 num_steps 500 time 11.98 done False
# episode  270 score -10000000.00 average score -9479800.00 epsilon 0.37 num_steps 500 time 12.45 done False
# episode  271 score -10000000.00 average score -9479800.00 epsilon 0.36 num_steps 500 time 12.45 done False
# episode  272 score -10000000.00 average score -9526800.00 epsilon 0.36 num_steps 500 time 11.87 done False
# episode  273 score -10000000.00 average score -9592800.00 epsilon 0.36 num_steps 500 time 12.30 done False
# episode  274 score -10000000.00 average score -9592800.00 epsilon 0.36 num_steps 500 time 12.76 done False
# episode  275 score -10000000.00 average score -9592800.00 epsilon 0.35 num_steps 500 time 13.94 done False
# episode  276 score -10000000.00 average score -9592800.00 epsilon 0.35 num_steps 500 time 13.03 done False
# episode  277 score -10000000.00 average score -9592800.00 epsilon 0.35 num_steps 500 time 11.96 done False
# episode  278 score -10000000.00 average score -9637800.00 epsilon 0.35 num_steps 500 time 12.19 done False
# episode  279 score -10000000.00 average score -9637800.00 epsilon 0.34 num_steps 500 time 12.70 done False
# episode  280 score -10000000.00 average score -9637800.00 epsilon 0.34 num_steps 500 time 12.02 done False
# episode  281 score -10000000.00 average score -9637800.00 epsilon 0.34 num_steps 500 time 11.90 done False
# episode  282 score -10000000.00 average score -9637800.00 epsilon 0.34 num_steps 500 time 12.28 done False
# episode  283 score -10000000.00 average score -9637800.00 epsilon 0.33 num_steps 500 time 15.40 done False
# episode  284 score -10000000.00 average score -9702400.00 epsilon 0.33 num_steps 500 time 13.93 done False
# episode  285 score -10000000.00 average score -9766800.00 epsilon 0.33 num_steps 500 time 13.84 done False
# episode  286 score -10000000.00 average score -9766800.00 epsilon 0.33 num_steps 500 time 12.93 done False
# episode  287 score -10000000.00 average score -9793400.00 epsilon 0.32 num_steps 500 time 12.64 done False
# episode  288 score -10000000.00 average score -9793400.00 epsilon 0.32 num_steps 500 time 12.62 done False
# episode  289 score -10000000.00 average score -9793400.00 epsilon 0.32 num_steps 500 time 12.60 done False
# episode  290 score -10000000.00 average score -9793400.00 epsilon 0.32 num_steps 500 time 15.64 done False
# episode  291 score -10000000.00 average score -9793400.00 epsilon 0.31 num_steps 500 time 14.15 done False
# episode  292 score -10000000.00 average score -9793400.00 epsilon 0.31 num_steps 500 time 16.07 done False
# episode  293 score -10000000.00 average score -9793400.00 epsilon 0.31 num_steps 500 time 13.16 done False
# episode  294 score -10000000.00 average score -9793400.00 epsilon 0.31 num_steps 500 time 13.70 done False
# episode  295 score -10000000.00 average score -9793400.00 epsilon 0.30 num_steps 500 time 14.44 done False
# episode  296 score -10000000.00 average score -9793400.00 epsilon 0.30 num_steps 500 time 16.53 done False
# episode  297 score -10000000.00 average score -9793400.00 epsilon 0.30 num_steps 500 time 14.70 done False
# episode  298 score -10000000.00 average score -9793400.00 epsilon 0.30 num_steps 500 time 14.62 done False
# episode  299 score -10000000.00 average score -9793400.00 epsilon 0.29 num_steps 500 time 15.32 done False
# episode  300 score -10000000.00 average score -9804000.00 epsilon 0.29 num_steps 500 time 14.58 done False
# episode  301 score -10000000.00 average score -9804000.00 epsilon 0.29 num_steps 500 time 14.52 done False
# episode  302 score -10000000.00 average score -9804000.00 epsilon 0.29 num_steps 500 time 15.05 done False
# episode  303 score -10000000.00 average score -9804000.00 epsilon 0.28 num_steps 500 time 15.27 done False
# episode  304 score -10000000.00 average score -9804000.00 epsilon 0.28 num_steps 500 time 14.09 done False
# episode  305 score -10000000.00 average score -9804000.00 epsilon 0.28 num_steps 500 time 15.50 done False
# episode  306 score -10000000.00 average score -9818600.00 epsilon 0.28 num_steps 500 time 15.39 done False
# episode  307 score -10000000.00 average score -9818600.00 epsilon 0.27 num_steps 500 time 14.87 done False
# episode  308 score -10000000.00 average score -9818600.00 epsilon 0.27 num_steps 500 time 14.42 done False
# episode  309 score -10000000.00 average score -9818600.00 epsilon 0.27 num_steps 500 time 14.70 done False
# episode  310 score -10000000.00 average score -9818600.00 epsilon 0.27 num_steps 500 time 14.35 done False
# episode  311 score -10000000.00 average score -9818600.00 epsilon 0.26 num_steps 500 time 17.81 done False
# episode  312 score -10000000.00 average score -9818600.00 epsilon 0.26 num_steps 500 time 21.33 done False
# episode  313 score -10000000.00 average score -9818600.00 epsilon 0.26 num_steps 500 time 18.56 done False
# episode  314 score -10000000.00 average score -9818600.00 epsilon 0.26 num_steps 500 time 24.41 done False
# episode  315 score -10000000.00 average score -9818600.00 epsilon 0.25 num_steps 500 time 19.32 done False
# episode  316 score -10000000.00 average score -9877200.00 epsilon 0.25 num_steps 500 time 18.38 done False
# episode  317 score -10000000.00 average score -9877200.00 epsilon 0.25 num_steps 500 time 18.47 done False
# episode  318 score -10000000.00 average score -9877200.00 epsilon 0.25 num_steps 500 time 18.48 done False
# episode  319 score -10000000.00 average score -9877200.00 epsilon 0.24 num_steps 500 time 21.14 done False
# episode  320 score -10000000.00 average score -9934400.00 epsilon 0.24 num_steps 500 time 20.60 done False
# episode  321 score -10000000.00 average score -9934400.00 epsilon 0.24 num_steps 500 time 18.37 done False
# episode  322 score -10000000.00 average score -9934400.00 epsilon 0.24 num_steps 500 time 17.78 done False
# episode  323 score -10000000.00 average score -9934400.00 epsilon 0.23 num_steps 500 time 24.49 done False
# episode  324 score -10000000.00 average score -9934400.00 epsilon 0.23 num_steps 500 time 18.55 done False
# episode  325 score -10000000.00 average score -9934400.00 epsilon 0.23 num_steps 500 time 18.84 done False
# episode  326 score -10000000.00 average score -9934400.00 epsilon 0.23 num_steps 500 time 18.07 done False
# episode  327 score -10000000.00 average score -9934400.00 epsilon 0.22 num_steps 500 time 19.02 done False
# episode  328 score -10000000.00 average score -9934400.00 epsilon 0.22 num_steps 500 time 17.90 done False
# episode  329 score -10000000.00 average score -9934400.00 epsilon 0.22 num_steps 500 time 18.35 done False
# episode  330 score -10000000.00 average score -9934400.00 epsilon 0.22 num_steps 500 time 18.86 done False
# episode  331 score -10000000.00 average score -9934400.00 epsilon 0.21 num_steps 500 time 18.00 done False
# episode  332 score -10000000.00 average score -9934400.00 epsilon 0.21 num_steps 500 time 19.75 done False
# episode  333 score -10000000.00 average score -9951000.00 epsilon 0.21 num_steps 500 time 18.40 done False
# episode  334 score -10000000.00 average score -9951000.00 epsilon 0.21 num_steps 500 time 19.74 done False
# episode  335 score -10000000.00 average score -9951000.00 epsilon 0.20 num_steps 500 time 18.59 done False
# episode  336 score -10000000.00 average score -9951000.00 epsilon 0.20 num_steps 500 time 19.07 done False
# episode  337 score -10000000.00 average score -9951000.00 epsilon 0.20 num_steps 500 time 18.85 done False
# episode  338 score -10000000.00 average score -9951000.00 epsilon 0.20 num_steps 500 time 20.00 done False
# episode  339 score -10000000.00 average score -9951000.00 epsilon 0.19 num_steps 500 time 20.73 done False
# episode  340 score -10000000.00 average score -9951000.00 epsilon 0.19 num_steps 500 time 17.91 done False
# episode  341 score -10000000.00 average score -9951000.00 epsilon 0.19 num_steps 500 time 17.90 done False
# episode  342 score -10000000.00 average score -9951000.00 epsilon 0.19 num_steps 500 time 18.89 done False
# episode  343 score -10000000.00 average score -9951000.00 epsilon 0.18 num_steps 500 time 18.52 done False
# episode  344 score -10000000.00 average score -9951000.00 epsilon 0.18 num_steps 500 time 18.86 done False
# episode  345 score -10000000.00 average score -9951000.00 epsilon 0.18 num_steps 500 time 18.53 done False
# episode  346 score -10000000.00 average score -9951000.00 epsilon 0.18 num_steps 500 time 21.22 done False
# episode  347 score -10000000.00 average score -9951000.00 epsilon 0.17 num_steps 500 time 20.00 done False
# episode  348 score -10000000.00 average score -9951000.00 epsilon 0.17 num_steps 500 time 21.01 done False
# episode  349 score -10000000.00 average score -9951000.00 epsilon 0.17 num_steps 500 time 18.36 done False
# episode  350 score -10000000.00 average score -9951000.00 epsilon 0.17 num_steps 500 time 20.38 done False
# episode  351 score -10000000.00 average score -9951000.00 epsilon 0.16 num_steps 500 time 18.64 done False
# episode  352 score -10000000.00 average score -9951000.00 epsilon 0.16 num_steps 500 time 18.19 done False
# episode  353 score -10000000.00 average score -9951000.00 epsilon 0.16 num_steps 500 time 19.69 done False
# episode  354 score -10000000.00 average score -9951000.00 epsilon 0.16 num_steps 500 time 18.54 done False
# episode  355 score -10000000.00 average score -9951000.00 epsilon 0.15 num_steps 500 time 20.19 done False
# episode  356 score -10000000.00 average score -9951000.00 epsilon 0.15 num_steps 500 time 18.26 done False
# episode  357 score -10000000.00 average score -9951000.00 epsilon 0.15 num_steps 500 time 18.38 done False
# episode  358 score -10000000.00 average score -9951000.00 epsilon 0.15 num_steps 500 time 19.34 done False
# episode  359 score -10000000.00 average score -9951000.00 epsilon 0.14 num_steps 500 time 27.28 done False
# episode  360 score -10000000.00 average score -9951000.00 epsilon 0.14 num_steps 500 time 23.41 done False
# episode  361 score -10000000.00 average score -9951000.00 epsilon 0.14 num_steps 500 time 20.43 done False
# episode  362 score -10000000.00 average score -10000000.00 epsilon 0.14 num_steps 500 time 18.69 done False
# episode  363 score -10000000.00 average score -10000000.00 epsilon 0.13 num_steps 500 time 20.25 done False
# episode  364 score -10000000.00 average score -10000000.00 epsilon 0.13 num_steps 500 time 20.43 done False
# episode  365 score -10000000.00 average score -10000000.00 epsilon 0.13 num_steps 500 time 22.11 done False
# episode  366 score -10000000.00 average score -10000000.00 epsilon 0.13 num_steps 500 time 18.98 done False
# episode  367 score -10000000.00 average score -10000000.00 epsilon 0.12 num_steps 500 time 18.23 done False
# episode  368 score -10000000.00 average score -10000000.00 epsilon 0.12 num_steps 500 time 20.77 done False
# episode  369 score -10000000.00 average score -10000000.00 epsilon 0.12 num_steps 500 time 23.28 done False
# episode  370 score -10000000.00 average score -10000000.00 epsilon 0.12 num_steps 500 time 20.55 done False
# episode  371 score -10000000.00 average score -10000000.00 epsilon 0.11 num_steps 500 time 20.47 done False
# episode  372 score -10000000.00 average score -10000000.00 epsilon 0.11 num_steps 500 time 23.24 done False
# episode  373 score -10000000.00 average score -10000000.00 epsilon 0.11 num_steps 500 time 22.56 done False
# episode  374 score -10000000.00 average score -10000000.00 epsilon 0.11 num_steps 500 time 20.74 done False
# episode  375 score -10000000.00 average score -10000000.00 epsilon 0.10 num_steps 500 time 23.25 done False
# episode  376 score -10000000.00 average score -10000000.00 epsilon 0.10 num_steps 500 time 20.48 done False
# episode  377 score -10000000.00 average score -10000000.00 epsilon 0.10 num_steps 500 time 20.22 done False
# episode  378 score -10000000.00 average score -10000000.00 epsilon 0.10 num_steps 500 time 20.96 done False
# episode  379 score -10000000.00 average score -10000000.00 epsilon 0.09 num_steps 500 time 19.34 done False
# episode  380 score -10000000.00 average score -10000000.00 epsilon 0.09 num_steps 500 time 19.55 done False
# episode  381 score -10000000.00 average score -10000000.00 epsilon 0.09 num_steps 500 time 19.70 done False
# episode  382 score -10000000.00 average score -10000000.00 epsilon 0.09 num_steps 500 time 20.65 done False
# episode  383 score -10000000.00 average score -10000000.00 epsilon 0.08 num_steps 500 time 21.80 done False
# episode  384 score -10000000.00 average score -10000000.00 epsilon 0.08 num_steps 500 time 22.65 done False
# episode  385 score -10000000.00 average score -10000000.00 epsilon 0.08 num_steps 500 time 21.64 done False
# episode  386 score -10000000.00 average score -10000000.00 epsilon 0.08 num_steps 500 time 19.78 done False
# episode  387 score -10000000.00 average score -10000000.00 epsilon 0.07 num_steps 500 time 19.56 done False
# episode  388 score -10000000.00 average score -10000000.00 epsilon 0.07 num_steps 500 time 19.48 done False
# episode  389 score -10000000.00 average score -10000000.00 epsilon 0.07 num_steps 500 time 19.48 done False
# episode  390 score -10000000.00 average score -10000000.00 epsilon 0.07 num_steps 500 time 19.91 done False
# episode  391 score -10000000.00 average score -10000000.00 epsilon 0.06 num_steps 500 time 19.73 done False
# episode  392 score -10000000.00 average score -10000000.00 epsilon 0.06 num_steps 500 time 25.50 done False
# episode  393 score -10000000.00 average score -10000000.00 epsilon 0.06 num_steps 500 time 19.65 done False
# episode  394 score -10000000.00 average score -10000000.00 epsilon 0.06 num_steps 500 time 19.61 done False
# episode  395 score -10000000.00 average score -10000000.00 epsilon 0.05 num_steps 500 time 18.77 done False
# episode  396 score -10000000.00 average score -10000000.00 epsilon 0.05 num_steps 500 time 19.04 done False
# episode  397 score -10000000.00 average score -10000000.00 epsilon 0.05 num_steps 500 time 17.52 done False
# episode  398 score -10000000.00 average score -10000000.00 epsilon 0.05 num_steps 500 time 20.96 done False
# episode  399 score -10000000.00 average score -10000000.00 epsilon 0.04 num_steps 500 time 19.80 done False
# episode  400 score -10000000.00 average score -10000000.00 epsilon 0.04 num_steps 500 time 18.89 done False
# episode  401 score -10000000.00 average score -10000000.00 epsilon 0.04 num_steps 500 time 18.50 done False
# episode  402 score -10000000.00 average score -10000000.00 epsilon 0.04 num_steps 500 time 19.73 done False
# episode  403 score -10000000.00 average score -10000000.00 epsilon 0.03 num_steps 500 time 21.14 done False
# episode  404 score -10000000.00 average score -10000000.00 epsilon 0.03 num_steps 500 time 20.20 done False
# episode  405 score -10000000.00 average score -10000000.00 epsilon 0.03 num_steps 500 time 19.04 done False
# episode  406 score -10000000.00 average score -10000000.00 epsilon 0.03 num_steps 500 time 20.05 done False
# episode  407 score -10000000.00 average score -10000000.00 epsilon 0.02 num_steps 500 time 19.07 done False
# episode  408 score -10000000.00 average score -10000000.00 epsilon 0.02 num_steps 500 time 28.16 done False
# episode  409 score -10000000.00 average score -10000000.00 epsilon 0.02 num_steps 500 time 23.96 done False
# episode  410 score -10000000.00 average score -10000000.00 epsilon 0.02 num_steps 500 time 20.81 done False
# episode  411 score -10000000.00 average score -10000000.00 epsilon 0.01 num_steps 500 time 24.69 done False
# episode  412 score -10000000.00 average score -10000000.00 epsilon 0.01 num_steps 500 time 24.15 done False
# episode  413 score -10000000.00 average score -10000000.00 epsilon 0.01 num_steps 500 time 23.12 done False
# episode  414 score -10000000.00 average score -10000000.00 epsilon 0.01 num_steps 500 time 31.57 done False
# episode  415 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 25.04 done False
# episode  416 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.64 done False
# episode  417 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 25.87 done False
# episode  418 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 25.26 done False
# episode  419 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 29.45 done False
# episode  420 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.38 done False
# episode  421 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 26.92 done False
# episode  422 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.48 done False
# episode  423 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 26.52 done False
# episode  424 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 27.93 done False
# episode  425 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 32.49 done False
# episode  426 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 25.16 done False
# episode  427 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 26.96 done False
# episode  428 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 28.74 done False
# episode  429 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 26.21 done False
# episode  430 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 29.55 done False
# episode  431 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.39 done False
# episode  432 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.85 done False
# episode  433 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.95 done False
# episode  434 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 25.70 done False
# episode  435 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.96 done False
# episode  436 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.11 done False
# episode  437 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.80 done False
# episode  438 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 31.69 done False
# episode  439 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 25.76 done False
# episode  440 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.48 done False
# episode  441 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.55 done False
# episode  442 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 28.83 done False
# episode  443 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.00 done False
# episode  444 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.89 done False
# episode  445 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 19.03 done False
# episode  446 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.25 done False
# episode  447 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 19.06 done False
# episode  448 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 18.62 done False
# episode  449 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 18.34 done False
# episode  450 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 18.76 done False
# episode  451 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 19.53 done False
# episode  452 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 17.70 done False
# episode  453 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.71 done False
# episode  454 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 18.56 done False
# episode  455 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.02 done False
# episode  456 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.05 done False
# episode  457 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.26 done False
# episode  458 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.51 done False
# episode  459 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 17.72 done False
# episode  460 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 18.62 done False
# episode  461 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 18.54 done False
# episode  462 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 19.47 done False
# episode  463 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 35.34 done False
# episode  464 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.00 done False
# episode  465 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.43 done False
# episode  466 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.48 done False
# episode  467 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.78 done False
# episode  468 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.06 done False
# episode  469 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.30 done False
# episode  470 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.10 done False
# episode  471 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.69 done False
# episode  472 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.95 done False
# episode  473 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.38 done False
# episode  474 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.12 done False
# episode  475 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.53 done False
# episode  476 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.38 done False
# episode  477 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.77 done False
# episode  478 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.53 done False
# episode  479 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.47 done False
# episode  480 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.47 done False
# episode  481 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.66 done False
# episode  482 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.04 done False
# episode  483 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.11 done False
# episode  484 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.94 done False
# episode  485 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.55 done False
# episode  486 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.55 done False
# episode  487 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.84 done False
# episode  488 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 24.40 done False
# episode  489 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.61 done False
# episode  490 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.32 done False
# episode  491 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 20.87 done False
# episode  492 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 22.65 done False
# episode  493 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.26 done False
# episode  494 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.38 done False
# episode  495 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.81 done False
# episode  496 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 21.99 done False
# episode  497 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.23 done False
# episode  498 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 23.88 done False
# episode  499 score -10000000.00 average score -10000000.00 epsilon 0.00 num_steps 500 time 29.13 done False

# %%
T.save(agent.Q_eval.state_dict(), 'q_eval_maze.pth')

# %%
T.load(agent.Q_eval.state_dict(), 'q_eval_maze.pth')

# infrence 
# env = gym.make('maze-sample-10x10-v0')
# observation = env.reset()
# done = False
# while not done:
#     action = agent.choose_action(observation)
#     observation_, reward, done, info = env.step(action)
#     observation = observation_


# import matplotlib.pyplot as plt
# x = [i+1 for i in range(n_games)]
# filename = agent_id + '_maze.png'
# fig = plt.figure()
# plt.plot(x, eps_history, label='epsilon')
# plt.plot(x, scores, label='score')
# plt.xlabel('training steps')
# plt.ylabel('score')
# plt.legend()
# plt.show()

# %%
print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# torch==1.13.1+cpu
# numpy==1.21.5
# json==2.0.9
# requests==2.27.1
# gym==0.26.2

# %% [markdown]
# ## dependencies
#
# - torch==1.13.1+cpu
# - numpy==1.21.5
# - json==2.0.9
# - requests==2.27.1
# - gym==0.26.2

# %% [markdown]
# # Kol El B3d kda maloo4 lazma /\/?

# %%
test =  [np.array((1,3)), [3,4,4,3], [[1,3], [2,4], [3,4], [4,4]]]

# %%
a = np.concatenate([[1,3], [2,4], [3,4], [4,4]])
input_data = [np.array((1,3)), [3,4,4,3],a]
output_vector = np.concatenate(input_data)

print(output_vector)

# %%
a = np.array([1, 3, 3, 4, 4, 3,1,3, 2, 4, 3, 4, 4, 4])
print(a)

# %%
np.concatenate([1 0],
[9, 7, 10, 3],
np.c[[1, 1], [0, 1], [1, 1], [1, 0]])

# %%
observation

# %%
print(observation[0])
print(observation[1])
print(observation[2])

# %%
np.concatenate([np.array([1, 0]), [8, 4, 10, 7], np.concatenate([[1, 1], [1, 1], [1, 1], [1, 1]])])

# %%
observation = np.concatenate([np.array([observation[0]]),np.array( observation[1]), observation[2]])
observation

# %%
observation

# %%
print(observation[0].shape)
print(np.array(observation[1]).shape)
print(np.array(observation[2]).flatten().shape)

# %%
observation = np.concatenate([np.array([[observation[0][0], observation[0][1]]]), observation[1], observation[2]])
observation

# %%
np.load("hackathon_sample.npy")
